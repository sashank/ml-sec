# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Read in the data from the CSV file
df = pd.read_csv('datasets/payment_fraud.csv')

# %%
df.sample(30)
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 1457             2000         1   4.921318        paypal
# 21891             259         1   4.962055        paypal
# 2195             2000         1   4.921349    creditcard
# 17539              73         1   5.017904        paypal
# 19386             210         1   4.876771    creditcard
# 2352              560         1   5.017904    creditcard
# 29461              25         1   4.921318    creditcard
# 37119              41         1   4.745402    creditcard
# 10210            2000         1   5.017904    creditcard
# 33937              57         1   4.057414    creditcard
# 37417             299         1   5.034622    creditcard
# 25484             827         1   5.034622   storecredit
# 15720            2000         1   5.034622   storecredit
# 34773            2000         1   4.876771    creditcard
# 31304            2000         1   4.742303    creditcard
# 38589            2000         1   4.962055    creditcard
# 25202            1018         1   5.034622   storecredit
# 23053              10         1   4.745402    creditcard
# 29672               2         1   4.962055    creditcard
# 18143               2         1   4.895263   storecredit
# 34370            2000         1   5.034622    creditcard
# 37321            1603         1   4.895263    creditcard
# 17153               5         1   4.836982        paypal
# 20781               2         1   4.965339    creditcard
# 24938            1278         1   5.034622        paypal
# 5780               77         1   5.017904        paypal
# 16372            2000         1   4.505662    creditcard
# 17123              38         1   4.886641    creditcard
# 7861              904         1   4.742303        paypal
# 28217               2         1   5.017904        paypal
#
#        paymentMethodAgeDays  label
# 1457             367.237500      0
# 21891              0.000000      0
# 2195               0.000000      0
# 17539              0.122222      0
# 19386              0.348611      0
# 2352             326.771528      0
# 29461              0.000000      0
# 37119              0.006250      0
# 10210           1920.043750      0
# 33937              0.002083      0
# 37417              0.000694      0
# 25484            208.020833      0
# 15720            532.209028      0
# 34773              0.002778      0
# 31304             44.729861      0
# 38589              0.000000      0
# 25202            774.137500      0
# 23053              0.000000      0
# 29672              1.083333      0
# 18143              1.915972      0
# 34370              0.000000      0
# 37321            197.018750      0
# 17153              0.000000      0
# 20781              1.120833      0
# 24938           1277.938889      0
# 5780               0.000000      0
# 16372            147.046528      0
# 17123              0.000000      0
# 7861               0.000000      0
# 28217              0.000000      0

# %%
# Convert categorical feature into dummy variables with one-hot encoding
df = pd.get_dummies(df, columns=['paymentMethod'])
df.sample(3)
# Out:
#        accountAgeDays  numItems  localTime  paymentMethodAgeDays  label  \
# 16056             474         1   4.836982            473.949306      0
# 10047             154         1   4.962055              0.000000      0
# 3867             2000         1   4.895263            311.559028      0
#
#        paymentMethod_creditcard  paymentMethod_paypal  \
# 16056                      True                 False
# 10047                      True                 False
# 3867                       True                 False
#
#        paymentMethod_storecredit
# 16056                      False
# 10047                      False
# 3867                       False

# %%
# Split dataset up into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('label', axis=1), df['label'],
    test_size=0.33, random_state=17)

# %%
# Initialize and train classifier model
clf = LogisticRegression().fit(X_train, y_train)

# Make predictions on test set
y_pred = clf.predict(X_test)

# %%
# Compare test set predictions with ground truth labels
print(accuracy_score(y_pred, y_test))
print(confusion_matrix(y_test, y_pred))
# Out:
# 1.0
# [[12753     0]
#  [    0   190]]
